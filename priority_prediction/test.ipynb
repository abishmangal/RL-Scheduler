# %%
import gymnasium as gym
import gym_env
import numpy as np

# %%
gym.envs.registry.keys().__contains__('gym_env/PriorityScheduler-v0')
# Out:
# True

# %%
dataset = np.genfromtxt("../dataset/test.csv", delimiter=',', skip_header=1)

# %%
env = gym.make("gym_env/PriorityScheduler-v0", data=dataset, encoder_context=5, max_priority=5, time_quantum = 4)

# %%
env.action_space.n
# Out:
# np.int64(5)

# %%
env.observation_space
# Out:
# Box(-1, 2147483647, (6, 5), int32)

# %%
en
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 en
#
# NameError: name 'en' is not defined

# %%
from ppo import PPO

# %%
model = PPO(env, 64)

# %%
model.learn(10000)

# %%
model.actor(np.zeros(shape=(30,))).detach().argmax()
# Out:
# tensor(2)

# %%
model.actor(np.ones(shape=(30,))).detach().argmax()
# Out:
# tensor(2)

# %%
model.actor(env.observation_space.sample().ravel()).detach().argmax()
# Out:
# tensor(2)

# %%
b = [[0, 1, 3, 3], [1, 1, 4, 4], [2, 6, 6, 6], [3, 6, 4, 4], [4, 10, 6, 6]]

# %%
[i[0] for i in b].index(2)
# Out:
# 2

# %%
from queue import PriorityQueue

# %%
queue = PriorityQueue()

# %%
a = [1, 2, 4, 5]

# %%
queue.put((1,a))
